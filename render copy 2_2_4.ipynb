# %%
import cv2
import torch
from modelscope.outputs import OutputKeys
from modelscope.pipelines import pipeline
from modelscope.utils.constant import Tasks

pasd = pipeline(Tasks.image_super_resolution_pasd, model='damo/PASD_v2_image_super_resolutions', version='pasd_v2')


def process_pic(input_location, output_image_path = 'result.png'):
    prompt = 'Cute girl,masterpiece, highly detailed'
   
    input = {
        'image': input_location,
        'prompt': prompt,
        'upscale': 2,
        'fidelity_scale_fg': 1.0,
        'fidelity_scale_bg': 1.0
    }
    
    output = pasd(input)[OutputKeys.OUTPUT_IMG]
    cv2.imwrite(output_image_path, output)
    print('pipeline: the output image path is {}'.format(output_image_path))
input_location = './output/0002.png'
process_pic(input_location, output_image_path = 'result.png')
#diffusers-0.28.2
# Out:
# Downloading Model to directory: C:\Users\Administrator\.cache\modelscope\hub\damo/PASD_v2_image_super_resolutions
# 2024-12-29 02:32:10,210 - modelscope - WARNING - Model revision not specified, use revision: v1.1.0
# 2024-12-29 02:32:10,845 - modelscope - INFO - initiate model from C:\Users\Administrator\.cache\modelscope\hub\damo\PASD_v2_image_super_resolutions
# 2024-12-29 02:32:10,846 - modelscope - INFO - initiate model from location C:\Users\Administrator\.cache\modelscope\hub\damo\PASD_v2_image_super_resolutions.
# 2024-12-29 02:32:10,852 - modelscope - WARNING - No preprocessor field found in cfg.
# 2024-12-29 02:32:10,852 - modelscope - WARNING - No val key and type key found in preprocessor domain of configuration.json file.
# 2024-12-29 02:32:10,852 - modelscope - WARNING - Cannot find available config to build preprocessor at mode inference, current config: {'model_dir': 'C:\\Users\\Administrator\\.cache\\modelscope\\hub\\damo\\PASD_v2_image_super_resolutions'}. trying to build by task and model information.
# 2024-12-29 02:32:10,853 - modelscope - WARNING - Find task: image-super-resolution-pasd, model type: None. Insufficient information to build preprocessor, skip building preprocessor
# e:\conda\envs\unique3d\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# e:\conda\envs\unique3d\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# e:\conda\envs\unique3d\Lib\site-packages\modelscope\models\cv\image_portrait_enhancement\retinaface\detection.py:63: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   pretrained_dict = torch.load(
#   0%|          | 0/20 [00:00<?, ?it/s]
# [Tiled VAE]: the input size is tiny and unnecessary to tile.
# pipeline: the output image path is result.png

# %%
import cv2
import numpy as np
import torch
from depth_anything_v2.dpt import DepthAnythingV2
import vtk
from PIL import Image
# Out:
# xFormers not available
# xFormers not available

# %%
import os
model = DepthAnythingV2(encoder='vitb', features=128, out_channels=[96, 192, 384, 768])
model.load_state_dict(torch.load('./checkpoints/depth_anything_v2_vitb.pth', map_location='cuda:0')) #cpu


# model = DepthAnythingV2(encoder='vits', features=64, out_channels=[48, 96, 192, 384])
# model.load_state_dict(torch.load('./checkpoints/depth_anything_v2_vits.pth', map_location='cuda:0'))

def pic23d(pic_path,fame_index = ""):

    if ".png"in pic_path or ".webp" in pic_path:
        image = Image.open(pic_path)  # 或者 "example.png"

        # 转换并保存为 JPG 格式
        pic_path = pic_path.replace(".webp",".jpg").replace(".png",".jpg")
        image.convert("RGB").save(pic_path, "JPEG")



    model.cuda().eval()   #   cpu model.eval() 

    raw_img = cv2.imread(pic_path)  
    height, width = raw_img.shape[:2]  
    target_height = 600  
    scale_ratio = target_height / height  
    target_width = int(width * scale_ratio)  
    raw_img = cv2.resize(raw_img, (target_width, target_height))  


    depth = model.infer_image(raw_img) # HxW raw depth map
    depth_normalized = cv2.normalize(depth, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)  
    depth_display = (depth_normalized * 255).astype(np.uint8)  # 转换为8位图像以便显示  
    cv2.imwrite('./depth_map.png', depth_display)  

    fx = 50  # 焦距x  
    fy = 50# 焦距y  
    cx = raw_img.shape[1] / 2.0  # 光心x  
    cy = raw_img.shape[0] / 2.0  # 光心y  
    height, width = raw_img.shape[:2]  
    
    # 推断深度图  
    depth_ = depth_display/255
    # 深度图可能需要归一化或转换到实际的深度值，这里假设它已经是所需的格式  
    
    # 创建一个空的数组来存储空间位置坐标  
    # 创建坐标网格，u 和 v 分别表示图像的列和行坐标
    u, v = np.meshgrid(np.arange(width), np.arange(height))

    # 计算空间坐标
    d = depth_.flatten()  # 展平深度图
    X = (1 - 0.5 * d) * (u.flatten() - cx) / fx
    Y = (1 - 0.5 * d) * (v.flatten() - cy) / fy
    Z = d * 10

    # 将结果组合成一个 (N, 3) 的坐标数组
    pos = np.vstack((X, Y, Z)).T  # 转置以便每行是 (X, Y, Z)
 


    with open("a.obj","w") as t:
        t.writelines("mtllib my_mtl.mtl"+"\n")
            
        for l in pos:
            L = "v "+str(l[0])+" "+str(l[1])+" "+str(l[2])+"\n"
            t.writelines(L )
        
        w_x = np.asarray([np.linspace(0.0, 1.0, num=width)]*height).reshape(width*height)
        h_y = np.asarray([np.linspace(1.0, 0.0, num=height)]*width).T.reshape(width*height)
        t_array_ = np.stack([w_x,h_y],axis=1)


        for i,j in t_array_:
            L = "vt " +str(i)+" "+str(j) +"\n"
            t.writelines(L )                
    #  
    #          
        t.writelines("\nusemtl my_mtl\n" )              
        b = np.array(range(height * width)).reshape([ height ,width])
        print(b.shape)  
                
        for i in range(1,b.shape[0]-1):
            for j in range(1,b.shape[1]-1):
                p = [ b[i,j] , b[i+1,j],b[i+1,j+1],b[i,j+1]]
        
                L = "f "+str(p[0])+"/"+ str(p[0])+" "+str(p[1])+"/"+ str(p[1])+" "+str(p[2])+"/"+ str(p[2])+" "+str(p[3])+"/"+ str(p[3])+"\n"
                t.writelines(L )
            


    with open("my_mtl.mtl","w") as m:  
        m.writelines(
    f"""
    newmtl my_mtl
    Ka 1 1 1
    Kd 1 1 1
    d 1
    Ns 0
    illum 1
    map_Kd {pic_path}
    """
        )



    image_size_x,image_size_y = raw_img.shape[:2] 
    def render_and_save_images(obj_file,   image_size=(int(image_size_x*1.6),int(image_size_y*1.6) ) ):
        # 读取模型
        reader = vtk.vtkOBJReader()
        reader.SetFileName(obj_file)
        reader.Update()

        # 创建一个映射器
        mapper = vtk.vtkPolyDataMapper()
        mapper.SetInputConnection(reader.GetOutputPort())

        # 创建一个演员
        actor = vtk.vtkActor()
        actor.SetMapper(mapper)

        # 读取贴图文件
        texture = vtk.vtkTexture()
        texture_reader = vtk.vtkJPEGReader()  # 假设贴图为JPEG格式
        texture_reader.SetFileName(pic_path)  # 根据.mtl文件中的路径设置
        texture_reader.Update()
        texture.SetInputConnection(texture_reader.GetOutputPort())
        
        # 将贴图应用到演员
        actor.SetTexture(texture)
        actor.SetOrientation(1,0,0)

        # 创建渲染窗口
        render_window = vtk.vtkRenderWindow()
        render_window.SetSize(image_size[1], image_size[0])  # 设置渲染窗口大小 

        # 创建左右视角的渲染器
        total_pic_count = 40
        renderers = []
        image_sequence = []
        for i in range(total_pic_count):
            renderer = vtk.vtkRenderer()
            render_window.AddRenderer(renderer)
            renderers.append(renderer)
            # 禁用光照
            renderer.SetAmbient(100.0, 100.0, 100.0)  # 设置环境光
            actor.GetProperty().SetLighting(False)
            # 设置摄像机
            camera = vtk.vtkCamera()
            
            camera.SetFocalPoint(0, 0, 0)
            # camera.SetParallelProjection(True)
            # # 正交投影参数
            # parallel_scale = 5.0  # 根据需求调整正交比例
            # camera.SetParallelScale(parallel_scale)
      
            camera.SetPosition(-4+i*0.2, 0, 20)  # 可以根据需要调整位置
            camera.SetViewUp(0, -1, 0)

            renderer.SetActiveCamera(camera)

            # 添加演员到渲染器
            renderer.AddActor(actor)
            renderer.SetBackground(0.0, 0.0, 0.0)  # 背景颜色

            # 渲染
            render_window.Render()

            # 保存图像
            window_to_image_filter = vtk.vtkWindowToImageFilter()
            window_to_image_filter.SetInput(render_window)
            window_to_image_filter.ReadFrontBufferOff()  # 读取后台缓冲区
            window_to_image_filter.Update()

            writer = vtk.vtkPNGWriter()
            #save_path

            if not os.path.exists('./output'):
                    os.makedirs('./output')            
            if fame_index=="":
                image_path = f"./output/{i:04d}.png"

            else:
                if not os.path.exists(f'./output/{i}/'):
                        os.makedirs(f'./output/{i}/')     

                image_path = f"./output/{i}/{fame_index}.png"  # f"./output/{i}/.png"


            writer.SetFileName(image_path)
            image_sequence.append(image_path)
            writer.SetInputConnection(window_to_image_filter.GetOutputPort())
            writer.Write()

        if fame_index=="":    
            # 获取视频的帧宽和帧高
            frame_width = image_size[1]
            frame_height = image_size[0]
            
            # 视频编码设置
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # 使用mp4v编码
            output_video = "output.mp4"
            video_writer = cv2.VideoWriter(output_video, fourcc, 30, (frame_width, frame_height))

            # 读取并写入每一帧
            for image_path in image_sequence:
                img = cv2.imread(image_path)
                video_writer.write(img)
            
            # 释放视频写入对象
            video_writer.release()
        

    render_and_save_images('a.obj' )


pic_path = "result.png"

pic23d(pic_path)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_32064\1053682486.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('./checkpoints/depth_anything_v2_vitb.pth', map_location='cuda:0')) #cpu
# (600, 472)

# %%
import cv2
import os

# 输入视频文件路径
video_path = '321049690463875079.mp4'
# 输出图片保存目录
output_dir = 'output_images/'

# 创建保存图片的目录，如果不存在
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# 打开视频文件
cap = cv2.VideoCapture(video_path)

# 获取视频的帧率
fps = cap.get(cv2.CAP_PROP_FPS)
# 获取视频的总帧数
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

frame_index = 0

# 读取每一帧
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # 如果读取不到帧，则退出

    # 构建输出图片的文件名
    output_file = os.path.join(output_dir, f"frame_{frame_index:04d}.png")
    
    # 保存当前帧为 PNG 图片
    cv2.imwrite(output_file, frame)
    
    print(f"保存帧 {frame_index + 1}/{frame_count} 到 {output_file}")

    frame_index += 1

# 释放视频对象
cap.release()
print("转换完成")
# Out:
# 保存帧 1/141 到 output_images/frame_0000.png
# 保存帧 2/141 到 output_images/frame_0001.png
# 保存帧 3/141 到 output_images/frame_0002.png
# 保存帧 4/141 到 output_images/frame_0003.png
# 保存帧 5/141 到 output_images/frame_0004.png
# 保存帧 6/141 到 output_images/frame_0005.png
# 保存帧 7/141 到 output_images/frame_0006.png
# 保存帧 8/141 到 output_images/frame_0007.png
# 保存帧 9/141 到 output_images/frame_0008.png
# 保存帧 10/141 到 output_images/frame_0009.png
# 保存帧 11/141 到 output_images/frame_0010.png
# 保存帧 12/141 到 output_images/frame_0011.png
# 保存帧 13/141 到 output_images/frame_0012.png
# 保存帧 14/141 到 output_images/frame_0013.png
# 保存帧 15/141 到 output_images/frame_0014.png
# 保存帧 16/141 到 output_images/frame_0015.png
# 保存帧 17/141 到 output_images/frame_0016.png
# 保存帧 18/141 到 output_images/frame_0017.png
# 保存帧 19/141 到 output_images/frame_0018.png
# 保存帧 20/141 到 output_images/frame_0019.png
# 保存帧 21/141 到 output_images/frame_0020.png
# 保存帧 22/141 到 output_images/frame_0021.png
# 保存帧 23/141 到 output_images/frame_0022.png
# 保存帧 24/141 到 output_images/frame_0023.png
# 保存帧 25/141 到 output_images/frame_0024.png
# 保存帧 26/141 到 output_images/frame_0025.png
# 保存帧 27/141 到 output_images/frame_0026.png
# 保存帧 28/141 到 output_images/frame_0027.png
# 保存帧 29/141 到 output_images/frame_0028.png
# 保存帧 30/141 到 output_images/frame_0029.png
# 保存帧 31/141 到 output_images/frame_0030.png
# 保存帧 32/141 到 output_images/frame_0031.png
# 保存帧 33/141 到 output_images/frame_0032.png
# 保存帧 34/141 到 output_images/frame_0033.png
# 保存帧 35/141 到 output_images/frame_0034.png
# 保存帧 36/141 到 output_images/frame_0035.png
# 保存帧 37/141 到 output_images/frame_0036.png
# 保存帧 38/141 到 output_images/frame_0037.png
# 保存帧 39/141 到 output_images/frame_0038.png
# 保存帧 40/141 到 output_images/frame_0039.png
# 保存帧 41/141 到 output_images/frame_0040.png
# 保存帧 42/141 到 output_images/frame_0041.png
# 保存帧 43/141 到 output_images/frame_0042.png
# 保存帧 44/141 到 output_images/frame_0043.png
# 保存帧 45/141 到 output_images/frame_0044.png
# 保存帧 46/141 到 output_images/frame_0045.png
# 保存帧 47/141 到 output_images/frame_0046.png
# 保存帧 48/141 到 output_images/frame_0047.png
# 保存帧 49/141 到 output_images/frame_0048.png
# 保存帧 50/141 到 output_images/frame_0049.png
# 保存帧 51/141 到 output_images/frame_0050.png
# 保存帧 52/141 到 output_images/frame_0051.png
# 保存帧 53/141 到 output_images/frame_0052.png
# 保存帧 54/141 到 output_images/frame_0053.png
# 保存帧 55/141 到 output_images/frame_0054.png
# 保存帧 56/141 到 output_images/frame_0055.png
# 保存帧 57/141 到 output_images/frame_0056.png
# 保存帧 58/141 到 output_images/frame_0057.png
# 保存帧 59/141 到 output_images/frame_0058.png
# 保存帧 60/141 到 output_images/frame_0059.png
# 保存帧 61/141 到 output_images/frame_0060.png
# 保存帧 62/141 到 output_images/frame_0061.png
# 保存帧 63/141 到 output_images/frame_0062.png
# 保存帧 64/141 到 output_images/frame_0063.png
# 保存帧 65/141 到 output_images/frame_0064.png
# 保存帧 66/141 到 output_images/frame_0065.png
# 保存帧 67/141 到 output_images/frame_0066.png
# 保存帧 68/141 到 output_images/frame_0067.png
# 保存帧 69/141 到 output_images/frame_0068.png
# 保存帧 70/141 到 output_images/frame_0069.png
# 保存帧 71/141 到 output_images/frame_0070.png
# 保存帧 72/141 到 output_images/frame_0071.png
# 保存帧 73/141 到 output_images/frame_0072.png
# 保存帧 74/141 到 output_images/frame_0073.png
# 保存帧 75/141 到 output_images/frame_0074.png
# 保存帧 76/141 到 output_images/frame_0075.png
# 保存帧 77/141 到 output_images/frame_0076.png
# 保存帧 78/141 到 output_images/frame_0077.png
# 保存帧 79/141 到 output_images/frame_0078.png
# 保存帧 80/141 到 output_images/frame_0079.png
# 保存帧 81/141 到 output_images/frame_0080.png
# 保存帧 82/141 到 output_images/frame_0081.png
# 保存帧 83/141 到 output_images/frame_0082.png
# 保存帧 84/141 到 output_images/frame_0083.png
# 保存帧 85/141 到 output_images/frame_0084.png
# 保存帧 86/141 到 output_images/frame_0085.png
# 保存帧 87/141 到 output_images/frame_0086.png
# 保存帧 88/141 到 output_images/frame_0087.png
# 保存帧 89/141 到 output_images/frame_0088.png
# 保存帧 90/141 到 output_images/frame_0089.png
# 保存帧 91/141 到 output_images/frame_0090.png
# 保存帧 92/141 到 output_images/frame_0091.png
# 保存帧 93/141 到 output_images/frame_0092.png
# 保存帧 94/141 到 output_images/frame_0093.png
# 保存帧 95/141 到 output_images/frame_0094.png
# 保存帧 96/141 到 output_images/frame_0095.png
# 保存帧 97/141 到 output_images/frame_0096.png
# 保存帧 98/141 到 output_images/frame_0097.png
# 保存帧 99/141 到 output_images/frame_0098.png
# 保存帧 100/141 到 output_images/frame_0099.png
# 保存帧 101/141 到 output_images/frame_0100.png
# 保存帧 102/141 到 output_images/frame_0101.png
# 保存帧 103/141 到 output_images/frame_0102.png
# 保存帧 104/141 到 output_images/frame_0103.png
# 保存帧 105/141 到 output_images/frame_0104.png
# 保存帧 106/141 到 output_images/frame_0105.png
# 保存帧 107/141 到 output_images/frame_0106.png
# 保存帧 108/141 到 output_images/frame_0107.png
# 保存帧 109/141 到 output_images/frame_0108.png
# 保存帧 110/141 到 output_images/frame_0109.png
# 保存帧 111/141 到 output_images/frame_0110.png
# 保存帧 112/141 到 output_images/frame_0111.png
# 保存帧 113/141 到 output_images/frame_0112.png
# 保存帧 114/141 到 output_images/frame_0113.png
# 保存帧 115/141 到 output_images/frame_0114.png
# 保存帧 116/141 到 output_images/frame_0115.png
# 保存帧 117/141 到 output_images/frame_0116.png
# 保存帧 118/141 到 output_images/frame_0117.png
# 保存帧 119/141 到 output_images/frame_0118.png
# 保存帧 120/141 到 output_images/frame_0119.png
# 保存帧 121/141 到 output_images/frame_0120.png
# 保存帧 122/141 到 output_images/frame_0121.png
# 保存帧 123/141 到 output_images/frame_0122.png
# 保存帧 124/141 到 output_images/frame_0123.png
# 保存帧 125/141 到 output_images/frame_0124.png
# 保存帧 126/141 到 output_images/frame_0125.png
# 保存帧 127/141 到 output_images/frame_0126.png
# 保存帧 128/141 到 output_images/frame_0127.png
# 保存帧 129/141 到 output_images/frame_0128.png
# 保存帧 130/141 到 output_images/frame_0129.png
# 保存帧 131/141 到 output_images/frame_0130.png
# 保存帧 132/141 到 output_images/frame_0131.png
# 保存帧 133/141 到 output_images/frame_0132.png
# 保存帧 134/141 到 output_images/frame_0133.png
# 保存帧 135/141 到 output_images/frame_0134.png
# 保存帧 136/141 到 output_images/frame_0135.png
# 保存帧 137/141 到 output_images/frame_0136.png
# 保存帧 138/141 到 output_images/frame_0137.png
# 保存帧 139/141 到 output_images/frame_0138.png
# 保存帧 140/141 到 output_images/frame_0139.png
# 保存帧 141/141 到 output_images/frame_0140.png
# 转换完成

# %%
frame_path = "./output_images/"
frame_list =[n for n in os.listdir(frame_path) if ".png" in n ] 
for frame_index, frame in enumerate(frame_list):
    
    pic_path = frame_path+frame
    print(frame_index,pic_path)
    pic23d(pic_path,frame_index)
# Out:
# 0 ./output_images/frame_0000.png
# (600, 473)
# 1 ./output_images/frame_0001.png
# (600, 473)
# 2 ./output_images/frame_0002.png
# (600, 473)
# 3 ./output_images/frame_0003.png
# (600, 473)
# 4 ./output_images/frame_0004.png
# (600, 473)
# 5 ./output_images/frame_0005.png
# (600, 473)
# 6 ./output_images/frame_0006.png
# (600, 473)
# 7 ./output_images/frame_0007.png
# (600, 473)
# 8 ./output_images/frame_0008.png
# (600, 473)
# 9 ./output_images/frame_0009.png
# (600, 473)
# 10 ./output_images/frame_0010.png
# (600, 473)
# 11 ./output_images/frame_0011.png
# (600, 473)
# 12 ./output_images/frame_0012.png
# (600, 473)
# 13 ./output_images/frame_0013.png
# (600, 473)
# 14 ./output_images/frame_0014.png
# (600, 473)
# 15 ./output_images/frame_0015.png
# (600, 473)
# 16 ./output_images/frame_0016.png
# (600, 473)
# 17 ./output_images/frame_0017.png
# (600, 473)
# 18 ./output_images/frame_0018.png
# (600, 473)
# 19 ./output_images/frame_0019.png
# (600, 473)
# 20 ./output_images/frame_0020.png
# (600, 473)
# 21 ./output_images/frame_0021.png
# (600, 473)
# 22 ./output_images/frame_0022.png
# (600, 473)
# 23 ./output_images/frame_0023.png
# (600, 473)
# 24 ./output_images/frame_0024.png
# (600, 473)
# 25 ./output_images/frame_0025.png
# (600, 473)
# 26 ./output_images/frame_0026.png
# (600, 473)
# 27 ./output_images/frame_0027.png
# (600, 473)
# 28 ./output_images/frame_0028.png
# (600, 473)
# 29 ./output_images/frame_0029.png
# (600, 473)
# 30 ./output_images/frame_0030.png
# (600, 473)
# 31 ./output_images/frame_0031.png
# (600, 473)
# 32 ./output_images/frame_0032.png
# (600, 473)
# 33 ./output_images/frame_0033.png
# (600, 473)
# 34 ./output_images/frame_0034.png
# (600, 473)
# 35 ./output_images/frame_0035.png
# (600, 473)
# 36 ./output_images/frame_0036.png
# (600, 473)
# 37 ./output_images/frame_0037.png
# (600, 473)
# 38 ./output_images/frame_0038.png
# (600, 473)
# 39 ./output_images/frame_0039.png
# (600, 473)
# 40 ./output_images/frame_0040.png
# (600, 473)
# 41 ./output_images/frame_0041.png
# (600, 473)
# 42 ./output_images/frame_0042.png
# (600, 473)
# 43 ./output_images/frame_0043.png
# (600, 473)
# 44 ./output_images/frame_0044.png
# (600, 473)
# 45 ./output_images/frame_0045.png
# (600, 473)
# 46 ./output_images/frame_0046.png
# (600, 473)
# 47 ./output_images/frame_0047.png
# (600, 473)
# 48 ./output_images/frame_0048.png
# (600, 473)
# 49 ./output_images/frame_0049.png
# (600, 473)
# 50 ./output_images/frame_0050.png
# (600, 473)
# 51 ./output_images/frame_0051.png
# (600, 473)
# 52 ./output_images/frame_0052.png
# (600, 473)
# 53 ./output_images/frame_0053.png
# (600, 473)
# 54 ./output_images/frame_0054.png
# (600, 473)
# 55 ./output_images/frame_0055.png
# (600, 473)
# 56 ./output_images/frame_0056.png
# (600, 473)
# 57 ./output_images/frame_0057.png
# (600, 473)
# 58 ./output_images/frame_0058.png
# (600, 473)
# 59 ./output_images/frame_0059.png
# (600, 473)
# 60 ./output_images/frame_0060.png
# (600, 473)
# 61 ./output_images/frame_0061.png
# (600, 473)
# 62 ./output_images/frame_0062.png
# (600, 473)
# 63 ./output_images/frame_0063.png
# (600, 473)
# 64 ./output_images/frame_0064.png
# (600, 473)
# 65 ./output_images/frame_0065.png
# (600, 473)
# 66 ./output_images/frame_0066.png
# (600, 473)
# 67 ./output_images/frame_0067.png
# (600, 473)
# 68 ./output_images/frame_0068.png
# (600, 473)
# 69 ./output_images/frame_0069.png
# (600, 473)
# 70 ./output_images/frame_0070.png
# (600, 473)
# 71 ./output_images/frame_0071.png
# (600, 473)
# 72 ./output_images/frame_0072.png
# (600, 473)
# 73 ./output_images/frame_0073.png
# (600, 473)
# 74 ./output_images/frame_0074.png
# (600, 473)
# 75 ./output_images/frame_0075.png
# (600, 473)
# 76 ./output_images/frame_0076.png
# (600, 473)
# 77 ./output_images/frame_0077.png
# (600, 473)
# 78 ./output_images/frame_0078.png
# (600, 473)
# 79 ./output_images/frame_0079.png
# (600, 473)
# 80 ./output_images/frame_0080.png
# (600, 473)
# 81 ./output_images/frame_0081.png
# (600, 473)
# 82 ./output_images/frame_0082.png
# (600, 473)
# 83 ./output_images/frame_0083.png
# (600, 473)
# 84 ./output_images/frame_0084.png
# (600, 473)
# 85 ./output_images/frame_0085.png
# (600, 473)
# 86 ./output_images/frame_0086.png
# (600, 473)
# 87 ./output_images/frame_0087.png
# (600, 473)
# 88 ./output_images/frame_0088.png
# (600, 473)
# 89 ./output_images/frame_0089.png
# (600, 473)
# 90 ./output_images/frame_0090.png
# (600, 473)
# 91 ./output_images/frame_0091.png
# (600, 473)
# 92 ./output_images/frame_0092.png
# (600, 473)
# 93 ./output_images/frame_0093.png
# (600, 473)
# 94 ./output_images/frame_0094.png
# (600, 473)
# 95 ./output_images/frame_0095.png
# (600, 473)
# 96 ./output_images/frame_0096.png
# (600, 473)
# 97 ./output_images/frame_0097.png
# (600, 473)
# 98 ./output_images/frame_0098.png
# (600, 473)
# 99 ./output_images/frame_0099.png
# (600, 473)
# 100 ./output_images/frame_0100.png
# (600, 473)
# 101 ./output_images/frame_0101.png
# (600, 473)
# 102 ./output_images/frame_0102.png
# (600, 473)
# 103 ./output_images/frame_0103.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 pic_path = frame_path+frame
#       6 print(frame_index,pic_path)
# ----> 7 pic23d(pic_path,frame_index)
#
# Cell In[2], line 74, in pic23d(pic_path, fame_index)
#      72     for i,j in t_array_:
#      73         L = "vt " +str(i)+" "+str(j) +"\n"
# ---> 74         t.writelines(L )
#      75 #
#      76 #
#      77     t.writelines("\nusemtl my_mtl\n" )
#
# KeyboardInterrupt:

# %%
# import requests
# from PIL import Image
# from io import BytesIO

# def upload_pic(pic_file_name, save_base="index.bin"):
#     im = Image.open(pic_file_name)
    
#     # Adjust the image size while maintaining the aspect ratio
#     original_width, original_height = im.size
#     target_height = 240
#     target_width = int((target_height / original_height) * original_width)
#     im = im.resize((target_width, target_height))  # Use LANCZOS filter for better quality

#     # Optionally, convert to RGB if the image has an alpha channel
#     if im.mode in ("RGBA", "LA") or (im.mode == "P" and "transparency" in im.info):
#         im = im.convert("RGB")

#     # Save as a binary file (using JPEG with adjustable quality)
#     img_byte = BytesIO()
#     im.save(img_byte, format='JPEG', quality=100)  # Adjust quality as needed
#     im.save("1.jpg", format='JPEG', quality=100)  # Adjust quality as needed
#     img_data = img_byte.getvalue()

#     # Write to binary file
#     with open(save_base, "wb") as f:
#         f.write(img_data)

# %%
import requests
from PIL import Image
from io import BytesIO

def upload_pic(pic_file_name, save_base="index.bin"):
    im = Image.open(pic_file_name)
    
    # 获取原始图像的宽度和高度
    original_width, original_height = im.size
    # 找出较大的维度并计算缩放比例
    if original_width > original_height:
        target_width = 240
        target_height = int((target_width / original_width) * original_height)
    else:
        target_height = 240
        target_width = int((target_height / original_height) * original_width)

    # 按比例缩放图像
    im = im.resize((target_width, target_height), Image.LANCZOS)

    # 创建一个 240x240 的黑色背景图像
    new_im = Image.new("RGB", (240, 240), (0, 0, 0))
    
    # 计算将缩放后的图像粘贴到黑色背景图像上的位置
    paste_x = (240 - target_width) // 2
    paste_y = (240 - target_height) // 2
    
    # 将缩放后的图像粘贴到黑色背景图像中
    new_im.paste(im, (paste_x, paste_y))
    
    # 可选：如果图像有透明通道，转换为RGB
    if new_im.mode in ("RGBA", "LA") or (new_im.mode == "P" and "transparency" in new_im.info):
        new_im = new_im.convert("RGB")
    
    # 将图像保存为二进制文件（使用JPEG格式并可以调整质量）
    img_byte = BytesIO()
    new_im.save(img_byte, format='JPEG', quality=100)  # 调整质量
    new_im.save("1.jpg", format='JPEG', quality=100)  # Adjust quality as needed

    img_data = img_byte.getvalue()
    
    # 将二进制数据写入文件
    with open(save_base, "wb") as f:
        f.write(img_data)

# %%
import os
pic_path = "output"

target_path = "15"
for i in range(0,40):
    for index, pic in enumerate(   sorted( os.listdir(pic_path+"/"+str(i)) ,key = lambda x: int(x.split(".")[0]))        ) :
        if ".jpg" in pic or ".png" in pic:
            # print(pic_path+pic)
            if not os.path.exists(f'F:/3d/{target_path}'):
                    os.makedirs(f'F:/3d/{target_path}')     
            if not os.path.exists(f"F:/3d/{target_path}/"+str(i)+"/"):
                os.mkdir(f"F:/3d/{target_path}/"+str(i)+"/")
            print(pic," "+str(index)+".bin")
            upload_pic(pic_path+"/"+str(i)+"/"+pic,f"F:/3d/{target_path}/"+str(i)+"/"+str(index)+".bin")
# Out:
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin
# 0.png  0.bin
# 1.png  1.bin
# 2.png  2.bin
# 3.png  3.bin
# 4.png  4.bin
# 5.png  5.bin
# 6.png  6.bin
# 7.png  7.bin
# 8.png  8.bin
# 9.png  9.bin
# 10.png  10.bin
# 11.png  11.bin
# 12.png  12.bin
# 13.png  13.bin
# 14.png  14.bin
# 15.png  15.bin
# 16.png  16.bin
# 17.png  17.bin
# 18.png  18.bin
# 19.png  19.bin
# 20.png  20.bin
# 21.png  21.bin
# 22.png  22.bin
# 23.png  23.bin
# 24.png  24.bin
# 25.png  25.bin
# 26.png  26.bin
# 27.png  27.bin
# 28.png  28.bin
# 29.png  29.bin
# 30.png  30.bin
# 31.png  31.bin
# 32.png  32.bin
# 33.png  33.bin
# 34.png  34.bin
# 35.png  35.bin
# 36.png  36.bin
# 37.png  37.bin
# 38.png  38.bin
# 39.png  39.bin
# 40.png  40.bin
# 41.png  41.bin
# 42.png  42.bin
# 43.png  43.bin
# 44.png  44.bin
# 45.png  45.bin
# 46.png  46.bin
# 47.png  47.bin
# 48.png  48.bin
# 49.png  49.bin
# 50.png  50.bin
# 51.png  51.bin
# 52.png  52.bin
# 53.png  53.bin
# 54.png  54.bin
# 55.png  55.bin
# 56.png  56.bin
# 57.png  57.bin
# 58.png  58.bin
# 59.png  59.bin
# 60.png  60.bin
# 61.png  61.bin
# 62.png  62.bin
# 63.png  63.bin
# 64.png  64.bin
# 65.png  65.bin
# 66.png  66.bin
# 67.png  67.bin
# 68.png  68.bin
# 69.png  69.bin
# 70.png  70.bin
# 71.png  71.bin
# 72.png  72.bin
# 73.png  73.bin
# 74.png  74.bin
# 75.png  75.bin
# 76.png  76.bin
# 77.png  77.bin
# 78.png  78.bin
# 79.png  79.bin
# 80.png  80.bin
# 81.png  81.bin
# 82.png  82.bin
# 83.png  83.bin
# 84.png  84.bin
# 85.png  85.bin
# 86.png  86.bin
# 87.png  87.bin
# 88.png  88.bin
# 89.png  89.bin
# 90.png  90.bin
# 91.png  91.bin
# 92.png  92.bin
# 93.png  93.bin
# 94.png  94.bin
# 95.png  95.bin
# 96.png  96.bin
# 97.png  97.bin
# 98.png  98.bin
# 99.png  99.bin
# 100.png  100.bin
# 101.png  101.bin
# 102.png  102.bin

# %%
with open(f"F:/3d/{target_path}/","w") as f_w:
     f_w .write(  """ {"frameCount":""" +100 +""","type":"movie","detailLevel":"""+ 40+"""} """)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 with open(f"F:/3d/{target_path}/","w") as f_w:
#       2      f_w .write(  """ {"frameCount":""" +100 +""","type":"movie","detailLevel":"""+ 40+"""} """)
#
# File e:\conda\envs\unique3d\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'F:/3d/15/'

# %%
#for comfyui 360


import cv2
import os
import numpy as np

def resize_frame(frame, target_size=240):
    """
    等比例缩放图像，将其最长边缩放到指定大小。

    :param frame: 输入的图像帧
    :param target_size: 目标大小，最长边将缩放到该大小
    :return: 缩放后的图像
    """
    # 获取图像的宽度和高度
    height, width = frame.shape[:2]
    
    # 选择最长边的尺寸
    if width > height:
        new_width = target_size
        new_height = int(target_size * height / width)
    else:
        new_height = target_size
        new_width = int(target_size * width / height)

    # 调整图像大小
    resized_frame = cv2.resize(frame, (new_width, new_height))
    return resized_frame

def place_on_black_background(frame, target_size=240):
    """
    将缩放后的图像居中放置在黑色背景上。

    :param frame: 输入的缩放后的图像
    :param target_size: 背景图像的目标大小（240x240）
    :return: 居中放置后的图像
    """
    # 创建黑色背景
    background = np.zeros((target_size, target_size, 3), dtype=np.uint8)

    # 获取缩放后图像的尺寸
    height, width = frame.shape[:2]

    # 计算图像放置的位置（居中）
    y_offset = (target_size - height) // 2
    x_offset = (target_size - width) // 2

    # 将图像放置到黑色背景的中心
    background[y_offset:y_offset + height, x_offset:x_offset + width] = frame

    return background

def extract_frames_from_video(video_path, output_folder='frames_output', target_size=240):
    """
    提取视频中的每一帧，缩放并将其居中放置在黑色背景上，然后保存到指定的子文件夹中。

    :param video_path: 输入的视频文件路径
    :param output_folder: 存储提取帧的根文件夹
    :param target_size: 目标尺寸，最长边将缩放到该大小
    """
    # 创建输出文件夹（如果不存在的话）
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 打开视频文件
    cap = cv2.VideoCapture(video_path)

    # 检查视频是否成功打开
    if not cap.isOpened():
        print(f"无法打开视频文件: {video_path}")
        return

    # 获取视频的总帧数
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    frame_index = 0

    while True:
        # 读取一帧
        ret, frame = cap.read()
        
        # 如果没有读取到帧，说明视频结束
        if not ret:
            break

        # 缩放图像
        resized_frame = resize_frame(frame, target_size)

        # 将缩放后的图像居中放置在黑色背景上
        final_frame = place_on_black_background(resized_frame, target_size)

        # 为每一帧创建子文件夹
        frame_folder = os.path.join(output_folder, f"{frame_index}")
        if not os.path.exists(frame_folder):
            os.makedirs(frame_folder)

        # 保存每一帧到子文件夹
     
        cv2.imwrite(os.path.join(frame_folder, f"0.jpg"), final_frame)
        cv2.imwrite(os.path.join(frame_folder, f"1.jpg"), final_frame)
        
        print(f"Frame {frame_index + 1}/{frame_count} saved")
        
        # 增加帧的索引
        frame_index += 1

    # 释放视频对象
    cap.release()

    print("视频帧提取、缩放并居中完成！")

# 示例使用
video_path = 'CogVideoX_Fun_orbits_00022.mp4'
extract_frames_from_video(video_path)





import os
pic_path = "frames_output"

target_path = "1"
for i in range(0,66):
    for index, pic in enumerate(   sorted( os.listdir(pic_path+"/"+str(i)) ,key = lambda x: int(x.split(".")[0]))        ) :
        if ".jpg" in pic or ".png" in pic:
            # print(pic_path+pic)
            if not os.path.exists(f'F:/3d/{target_path}'):
                    os.makedirs(f'F:/3d/{target_path}')     
            if not os.path.exists(f"F:/3d/{target_path}/"+str(i)+"/"):
                os.mkdir(f"F:/3d/{target_path}/"+str(i)+"/")
            print(pic," "+str(index)+".bin")
            upload_pic(pic_path+"/"+str(i)+"/"+pic,f"F:/3d/{target_path}/"+str(i)+"/"+str(index)+".bin")
# Out:
# Frame 1/66 saved
# Frame 2/66 saved
# Frame 3/66 saved
# Frame 4/66 saved
# Frame 5/66 saved
# Frame 6/66 saved
# Frame 7/66 saved
# Frame 8/66 saved
# Frame 9/66 saved
# Frame 10/66 saved
# Frame 11/66 saved
# Frame 12/66 saved
# Frame 13/66 saved
# Frame 14/66 saved
# Frame 15/66 saved
# Frame 16/66 saved
# Frame 17/66 saved
# Frame 18/66 saved
# Frame 19/66 saved
# Frame 20/66 saved
# Frame 21/66 saved
# Frame 22/66 saved
# Frame 23/66 saved
# Frame 24/66 saved
# Frame 25/66 saved
# Frame 26/66 saved
# Frame 27/66 saved
# Frame 28/66 saved
# Frame 29/66 saved
# Frame 30/66 saved
# Frame 31/66 saved
# Frame 32/66 saved
# Frame 33/66 saved
# Frame 34/66 saved
# Frame 35/66 saved
# Frame 36/66 saved
# Frame 37/66 saved
# Frame 38/66 saved
# Frame 39/66 saved
# Frame 40/66 saved
# Frame 41/66 saved
# Frame 42/66 saved
# Frame 43/66 saved
# Frame 44/66 saved
# Frame 45/66 saved
# Frame 46/66 saved
# Frame 47/66 saved
# Frame 48/66 saved
# Frame 49/66 saved
# Frame 50/66 saved
# Frame 51/66 saved
# Frame 52/66 saved
# Frame 53/66 saved
# Frame 54/66 saved
# Frame 55/66 saved
# Frame 56/66 saved
# Frame 57/66 saved
# Frame 58/66 saved
# Frame 59/66 saved
# Frame 60/66 saved
# Frame 61/66 saved
# Frame 62/66 saved
# Frame 63/66 saved
# Frame 64/66 saved
# Frame 65/66 saved
# Frame 66/66 saved
# 视频帧提取、缩放并居中完成！
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin
# 0.jpg  0.bin
# 1.jpg  1.bin

# %%
import bpy
import os

# 设置保存路径



# 获取场景中的Cube对象
cube = bpy.data.objects.get("圆环")
if not cube:
    raise ValueError("找不到名为 'Cube' 的对象，请确保它存在")

# 配置渲染设置
bpy.context.scene.render.image_settings.file_format = 'PNG'  # 渲染为PNG格式
bpy.context.scene.render.resolution_x = 800  # 宽度
bpy.context.scene.render.resolution_y = 800  # 高度

# 旋转和渲染逻辑
for index, i in enumerate( list( range(-180, 180, 5))):
    
    save_path = f"C:/Users/Administrator/Pictures/blender_gif/{index}/"
    os.makedirs(save_path, exist_ok=True)
    
    # 旋转Cube对象
    cube.rotation_euler[2] = i * (3.14159 / 180)  # 将角度转换为弧度
    
    for frame in range(1,43):
    
        # 设置帧号（用于保存文件名）
        bpy.context.scene.frame_set(frame)  # 每5度为一帧
    
        # 设置输出文件路径
        file_name = f"{frame}.png"
        bpy.context.scene.render.filepath = os.path.join(save_path, file_name)
    
        # 渲染当前帧
        #bpy.ops.render.render(write_still=True)
        bpy.ops.render.opengl(write_still=True, view_context=True)
    index+=1
  

print("渲染完成！所有图片保存在：", save_path)

# %%
import cv2
import os
import numpy as np

def resize_frame(frame, target_size=240):
    """
    等比例缩放图像，将其最长边缩放到指定大小。

    :param frame: 输入的图像帧
    :param target_size: 目标大小，最长边将缩放到该大小
    :return: 缩放后的图像
    """
    # 获取图像的宽度和高度
    height, width = frame.shape[:2]
    
    # 选择最长边的尺寸
    if width > height:
        new_width = target_size
        new_height = int(target_size * height / width)
    else:
        new_height = target_size
        new_width = int(target_size * width / height)

    # 调整图像大小
    resized_frame = cv2.resize(frame, (new_width, new_height))
    return resized_frame

def place_on_black_background(frame, target_size=240):
    """
    将缩放后的图像居中放置在黑色背景上。

    :param frame: 输入的缩放后的图像
    :param target_size: 背景图像的目标大小（240x240）
    :return: 居中放置后的图像
    """
    # 创建黑色背景
    background = np.zeros((target_size, target_size, 3), dtype=np.uint8)

    # 获取缩放后图像的尺寸
    height, width = frame.shape[:2]

    # 计算图像放置的位置（居中）
    y_offset = (target_size - height) // 2
    x_offset = (target_size - width) // 2

    # 将图像放置到黑色背景的中心
    background[y_offset:y_offset + height, x_offset:x_offset + width] = frame

    return background

def extract_frames_from_video(video_path, output_folder='frames_output', target_size=240):
    """
    提取视频中的每一帧，缩放并将其居中放置在黑色背景上，然后保存到指定的子文件夹中。

    :param video_path: 输入的视频文件路径
    :param output_folder: 存储提取帧的根文件夹
    :param target_size: 目标尺寸，最长边将缩放到该大小
    """
    # 创建输出文件夹（如果不存在的话）
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 打开视频文件
    cap = cv2.VideoCapture(video_path)

    # 检查视频是否成功打开
    if not cap.isOpened():
        print(f"无法打开视频文件: {video_path}")
        return

    # 获取视频的总帧数
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    frame_index = 0

    while True:
        # 读取一帧
        ret, frame = cap.read()
        
        # 如果没有读取到帧，说明视频结束
        if not ret:
            break

        # 缩放图像
        resized_frame = resize_frame(frame, target_size)

        # 将缩放后的图像居中放置在黑色背景上
        final_frame = place_on_black_background(resized_frame, target_size)

        # 为每一帧创建子文件夹
        frame_folder = os.path.join(output_folder, f"{frame_index}")
        if not os.path.exists(frame_folder):
            os.makedirs(frame_folder)

        # 保存每一帧到子文件夹
        frame_filename = os.path.join(frame_folder, f"{frame_index}.jpg")
        cv2.imwrite(frame_filename, final_frame)
        
        print(f"Frame {frame_index + 1}/{frame_count} saved to {frame_filename}")
        
        # 增加帧的索引
        frame_index += 1

    # 释放视频对象
    cap.release()

    print("视频帧提取、缩放并居中完成！")


# 示例使用
video_path = 'CogVideoX_Fun_orbits_00005.mp4'
extract_frames_from_video(video_path)
# Out:
# Frame 1/66 saved to frames_output\0\0.jpg
# Frame 2/66 saved to frames_output\1\1.jpg
# Frame 3/66 saved to frames_output\2\2.jpg
# Frame 4/66 saved to frames_output\3\3.jpg
# Frame 5/66 saved to frames_output\4\4.jpg
# Frame 6/66 saved to frames_output\5\5.jpg
# Frame 7/66 saved to frames_output\6\6.jpg
# Frame 8/66 saved to frames_output\7\7.jpg
# Frame 9/66 saved to frames_output\8\8.jpg
# Frame 10/66 saved to frames_output\9\9.jpg
# Frame 11/66 saved to frames_output\10\10.jpg
# Frame 12/66 saved to frames_output\11\11.jpg
# Frame 13/66 saved to frames_output\12\12.jpg
# Frame 14/66 saved to frames_output\13\13.jpg
# Frame 15/66 saved to frames_output\14\14.jpg
# Frame 16/66 saved to frames_output\15\15.jpg
# Frame 17/66 saved to frames_output\16\16.jpg
# Frame 18/66 saved to frames_output\17\17.jpg
# Frame 19/66 saved to frames_output\18\18.jpg
# Frame 20/66 saved to frames_output\19\19.jpg
# Frame 21/66 saved to frames_output\20\20.jpg
# Frame 22/66 saved to frames_output\21\21.jpg
# Frame 23/66 saved to frames_output\22\22.jpg
# Frame 24/66 saved to frames_output\23\23.jpg
# Frame 25/66 saved to frames_output\24\24.jpg
# Frame 26/66 saved to frames_output\25\25.jpg
# Frame 27/66 saved to frames_output\26\26.jpg
# Frame 28/66 saved to frames_output\27\27.jpg
# Frame 29/66 saved to frames_output\28\28.jpg
# Frame 30/66 saved to frames_output\29\29.jpg
# Frame 31/66 saved to frames_output\30\30.jpg
# Frame 32/66 saved to frames_output\31\31.jpg
# Frame 33/66 saved to frames_output\32\32.jpg
# Frame 34/66 saved to frames_output\33\33.jpg
# Frame 35/66 saved to frames_output\34\34.jpg
# Frame 36/66 saved to frames_output\35\35.jpg
# Frame 37/66 saved to frames_output\36\36.jpg
# Frame 38/66 saved to frames_output\37\37.jpg
# Frame 39/66 saved to frames_output\38\38.jpg
# Frame 40/66 saved to frames_output\39\39.jpg
# Frame 41/66 saved to frames_output\40\40.jpg
# Frame 42/66 saved to frames_output\41\41.jpg
# Frame 43/66 saved to frames_output\42\42.jpg
# Frame 44/66 saved to frames_output\43\43.jpg
# Frame 45/66 saved to frames_output\44\44.jpg
# Frame 46/66 saved to frames_output\45\45.jpg
# Frame 47/66 saved to frames_output\46\46.jpg
# Frame 48/66 saved to frames_output\47\47.jpg
# Frame 49/66 saved to frames_output\48\48.jpg
# Frame 50/66 saved to frames_output\49\49.jpg
# Frame 51/66 saved to frames_output\50\50.jpg
# Frame 52/66 saved to frames_output\51\51.jpg
# Frame 53/66 saved to frames_output\52\52.jpg
# Frame 54/66 saved to frames_output\53\53.jpg
# Frame 55/66 saved to frames_output\54\54.jpg
# Frame 56/66 saved to frames_output\55\55.jpg
# Frame 57/66 saved to frames_output\56\56.jpg
# Frame 58/66 saved to frames_output\57\57.jpg
# Frame 59/66 saved to frames_output\58\58.jpg
# Frame 60/66 saved to frames_output\59\59.jpg
# Frame 61/66 saved to frames_output\60\60.jpg
# Frame 62/66 saved to frames_output\61\61.jpg
# Frame 63/66 saved to frames_output\62\62.jpg
# Frame 64/66 saved to frames_output\63\63.jpg
# Frame 65/66 saved to frames_output\64\64.jpg
# Frame 66/66 saved to frames_output\65\65.jpg
# 视频帧提取、缩放并居中完成！

# %%
from moviepy import VideoFileClip, ImageSequenceClip
from PIL import Image
import numpy as np

# 定义屏幕宽高
screen_width = 368
screen_height = 552

# 输入和输出视频文件路径
input_video_path = 'CogVideoX_Fun_orbits_00005.mp4'
output_video_path = 'output_video.mp4'

# 设置模式：1表示原来处理方式，2表示避免黑边的处理方式
mode = 2  # 设置为1或2

def process_frame(frame, mode):
    """处理每一帧：根据模式进行处理"""
    # 转换为Pillow图像对象
    pil_image = Image.fromarray(frame)
    
    # 获取原始视频帧的宽高
    original_width, original_height = pil_image.size

    if mode == 1:
        # 模式1: 缩放帧，保持宽高比例，再裁剪到目标尺寸（可能会有黑边）
        pil_image = pil_image.resize((int(original_width * min(screen_width / original_width, screen_height / original_height)), 
                                      int(original_height * min(screen_width / original_width, screen_height / original_height))))
        
        # 计算裁剪区域，按中心裁剪
        left = (pil_image.width - screen_width) / 2
        top = (pil_image.height - screen_height) / 2
        right = (pil_image.width + screen_width) / 2
        bottom = (pil_image.height + screen_height) / 2
        
        # 裁剪图像
        pil_image = pil_image.crop((left, top, right, bottom))
        
    elif mode == 2:
        # 模式2: 按屏幕宽高比裁剪视频，避免黑边
        screen_ratio = screen_width / screen_height
        video_ratio = original_width / original_height

        if video_ratio > screen_ratio:
            # 视频宽高比大于屏幕宽高比，裁剪宽度
            new_width = int(original_height * screen_ratio)
            left = (original_width - new_width) / 2
            pil_image = pil_image.crop((left, 0, left + new_width, original_height))
        elif video_ratio < screen_ratio:
            # 视频宽高比小于屏幕宽高比，裁剪高度
            new_height = int(original_width / screen_ratio)
            top = (original_height - new_height) / 2
            pil_image = pil_image.crop((0, top, original_width, top + new_height))
        # 如果视频宽高比等于屏幕宽高比，则不做裁剪，直接缩放
        
        # 缩放到目标尺寸
        pil_image = pil_image.resize((screen_width, screen_height))
        

    # 转换回NumPy数组
    return np.array(pil_image)

# 加载输入视频
clip = VideoFileClip(input_video_path)

# 使用 iter_frames 获取每一帧并处理
frames = []
for frame in clip.iter_frames(fps=clip.fps, dtype='uint8'):
    processed_frame = process_frame(frame, mode)
    frames.append(processed_frame)

# 使用处理后的帧生成新的视频
processed_clip = ImageSequenceClip(frames, fps=clip.fps)

# 输出处理后的视频
processed_clip.write_videofile(output_video_path, codec="libx264", fps=clip.fps)
# Out:
# MoviePy - Building video output_video.mp4.
# MoviePy - Writing video output_video.mp4
# MoviePy - Done !
# MoviePy - video ready output_video.mp4

# %%
# !pip show moviepy
# Out:
# 'pip' �����ڲ����ⲿ���Ҳ���ǿ����еĳ���
# ���������ļ���

# %%
import cv2
import os
import numpy as np

# 配置
video_path = "input_video.mp4"  # 输入视频路径
output_folder = "framebuffer_frames"  # 输出文件夹
screen_width = int(368)
screen_height = int(552)

# 创建输出文件夹
os.makedirs(output_folder, exist_ok=True)

# 打开视频文件
cap = cv2.VideoCapture(video_path)

frame_index = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # 调整帧大小到屏幕分辨率
    frame = cv2.resize(frame, (screen_width, screen_height))

    # 转换颜色空间 BGR -> BGRA
    frame_bgra = cv2.cvtColor(frame, cv2.COLOR_BGR2BGRA)

    # 保存为 framebuffer.raw 文件
    raw_file_path = os.path.join(output_folder, f"{frame_index:05d}.raw")
    with open(raw_file_path, "wb") as raw_file:
        raw_file.write(frame_bgra.tobytes())

    print(f"Saved frame {frame_index} as {raw_file_path}")
    frame_index += 1

cap.release()
print(f"Finished extracting frames. Total frames: {frame_index}")
# Out:
# Saved frame 0 as framebuffer_frames\00000.raw
# Saved frame 1 as framebuffer_frames\00001.raw
# Saved frame 2 as framebuffer_frames\00002.raw
# Saved frame 3 as framebuffer_frames\00003.raw
# Saved frame 4 as framebuffer_frames\00004.raw
# Saved frame 5 as framebuffer_frames\00005.raw
# Saved frame 6 as framebuffer_frames\00006.raw
# Saved frame 7 as framebuffer_frames\00007.raw
# Saved frame 8 as framebuffer_frames\00008.raw
# Saved frame 9 as framebuffer_frames\00009.raw
# Saved frame 10 as framebuffer_frames\00010.raw
# Saved frame 11 as framebuffer_frames\00011.raw
# Saved frame 12 as framebuffer_frames\00012.raw
# Saved frame 13 as framebuffer_frames\00013.raw
# Saved frame 14 as framebuffer_frames\00014.raw
# Saved frame 15 as framebuffer_frames\00015.raw
# Saved frame 16 as framebuffer_frames\00016.raw
# Saved frame 17 as framebuffer_frames\00017.raw
# Saved frame 18 as framebuffer_frames\00018.raw
# Saved frame 19 as framebuffer_frames\00019.raw
# Saved frame 20 as framebuffer_frames\00020.raw
# Saved frame 21 as framebuffer_frames\00021.raw
# Saved frame 22 as framebuffer_frames\00022.raw
# Saved frame 23 as framebuffer_frames\00023.raw
# Saved frame 24 as framebuffer_frames\00024.raw
# Saved frame 25 as framebuffer_frames\00025.raw
# Saved frame 26 as framebuffer_frames\00026.raw
# Saved frame 27 as framebuffer_frames\00027.raw
# Saved frame 28 as framebuffer_frames\00028.raw
# Saved frame 29 as framebuffer_frames\00029.raw
# Saved frame 30 as framebuffer_frames\00030.raw
# Saved frame 31 as framebuffer_frames\00031.raw
# Saved frame 32 as framebuffer_frames\00032.raw
# Saved frame 33 as framebuffer_frames\00033.raw
# Saved frame 34 as framebuffer_frames\00034.raw
# Saved frame 35 as framebuffer_frames\00035.raw
# Saved frame 36 as framebuffer_frames\00036.raw
# Saved frame 37 as framebuffer_frames\00037.raw
# Saved frame 38 as framebuffer_frames\00038.raw
# Saved frame 39 as framebuffer_frames\00039.raw
# Saved frame 40 as framebuffer_frames\00040.raw
# Saved frame 41 as framebuffer_frames\00041.raw
# Saved frame 42 as framebuffer_frames\00042.raw
# Saved frame 43 as framebuffer_frames\00043.raw
# Saved frame 44 as framebuffer_frames\00044.raw
# Saved frame 45 as framebuffer_frames\00045.raw
# Saved frame 46 as framebuffer_frames\00046.raw
# Saved frame 47 as framebuffer_frames\00047.raw
# Saved frame 48 as framebuffer_frames\00048.raw
# Saved frame 49 as framebuffer_frames\00049.raw
# Saved frame 50 as framebuffer_frames\00050.raw
# Saved frame 51 as framebuffer_frames\00051.raw
# Saved frame 52 as framebuffer_frames\00052.raw
# Saved frame 53 as framebuffer_frames\00053.raw
# Saved frame 54 as framebuffer_frames\00054.raw
# Saved frame 55 as framebuffer_frames\00055.raw
# Saved frame 56 as framebuffer_frames\00056.raw
# Saved frame 57 as framebuffer_frames\00057.raw
# Saved frame 58 as framebuffer_frames\00058.raw
# Saved frame 59 as framebuffer_frames\00059.raw
# Saved frame 60 as framebuffer_frames\00060.raw
# Saved frame 61 as framebuffer_frames\00061.raw
# Saved frame 62 as framebuffer_frames\00062.raw
# Saved frame 63 as framebuffer_frames\00063.raw
# Saved frame 64 as framebuffer_frames\00064.raw
# Saved frame 65 as framebuffer_frames\00065.raw
# Saved frame 66 as framebuffer_frames\00066.raw
# Saved frame 67 as framebuffer_frames\00067.raw
# Saved frame 68 as framebuffer_frames\00068.raw
# Saved frame 69 as framebuffer_frames\00069.raw
# Saved frame 70 as framebuffer_frames\00070.raw
# Saved frame 71 as framebuffer_frames\00071.raw
# Saved frame 72 as framebuffer_frames\00072.raw
# Saved frame 73 as framebuffer_frames\00073.raw
# Saved frame 74 as framebuffer_frames\00074.raw
# Saved frame 75 as framebuffer_frames\00075.raw
# Saved frame 76 as framebuffer_frames\00076.raw
# Saved frame 77 as framebuffer_frames\00077.raw
# Saved frame 78 as framebuffer_frames\00078.raw
# Saved frame 79 as framebuffer_frames\00079.raw
# Saved frame 80 as framebuffer_frames\00080.raw
# Saved frame 81 as framebuffer_frames\00081.raw
# Saved frame 82 as framebuffer_frames\00082.raw
# Saved frame 83 as framebuffer_frames\00083.raw
# Saved frame 84 as framebuffer_frames\00084.raw
# Saved frame 85 as framebuffer_frames\00085.raw
# Saved frame 86 as framebuffer_frames\00086.raw
# Saved frame 87 as framebuffer_frames\00087.raw
# Saved frame 88 as framebuffer_frames\00088.raw
# Saved frame 89 as framebuffer_frames\00089.raw
# Saved frame 90 as framebuffer_frames\00090.raw
# Saved frame 91 as framebuffer_frames\00091.raw
# Saved frame 92 as framebuffer_frames\00092.raw
# Saved frame 93 as framebuffer_frames\00093.raw
# Saved frame 94 as framebuffer_frames\00094.raw
# Saved frame 95 as framebuffer_frames\00095.raw
# Saved frame 96 as framebuffer_frames\00096.raw
# Saved frame 97 as framebuffer_frames\00097.raw
# Saved frame 98 as framebuffer_frames\00098.raw
# Saved frame 99 as framebuffer_frames\00099.raw
# Saved frame 100 as framebuffer_frames\00100.raw
# Saved frame 101 as framebuffer_frames\00101.raw
# Saved frame 102 as framebuffer_frames\00102.raw
# Saved frame 103 as framebuffer_frames\00103.raw
# Saved frame 104 as framebuffer_frames\00104.raw
# Saved frame 105 as framebuffer_frames\00105.raw
# Saved frame 106 as framebuffer_frames\00106.raw
# Saved frame 107 as framebuffer_frames\00107.raw
# Saved frame 108 as framebuffer_frames\00108.raw
# Saved frame 109 as framebuffer_frames\00109.raw
# Saved frame 110 as framebuffer_frames\00110.raw
# Saved frame 111 as framebuffer_frames\00111.raw
# Saved frame 112 as framebuffer_frames\00112.raw
# Saved frame 113 as framebuffer_frames\00113.raw
# Saved frame 114 as framebuffer_frames\00114.raw
# Saved frame 115 as framebuffer_frames\00115.raw
# Saved frame 116 as framebuffer_frames\00116.raw
# Saved frame 117 as framebuffer_frames\00117.raw
# Saved frame 118 as framebuffer_frames\00118.raw
# Saved frame 119 as framebuffer_frames\00119.raw
# Saved frame 120 as framebuffer_frames\00120.raw
# Saved frame 121 as framebuffer_frames\00121.raw
# Saved frame 122 as framebuffer_frames\00122.raw
# Saved frame 123 as framebuffer_frames\00123.raw
# Saved frame 124 as framebuffer_frames\00124.raw
# Saved frame 125 as framebuffer_frames\00125.raw
# Saved frame 126 as framebuffer_frames\00126.raw
# Saved frame 127 as framebuffer_frames\00127.raw
# Saved frame 128 as framebuffer_frames\00128.raw
# Saved frame 129 as framebuffer_frames\00129.raw
# Saved frame 130 as framebuffer_frames\00130.raw
# Saved frame 131 as framebuffer_frames\00131.raw
# Saved frame 132 as framebuffer_frames\00132.raw
# Saved frame 133 as framebuffer_frames\00133.raw
# Saved frame 134 as framebuffer_frames\00134.raw
# Saved frame 135 as framebuffer_frames\00135.raw
# Saved frame 136 as framebuffer_frames\00136.raw
# Saved frame 137 as framebuffer_frames\00137.raw
# Saved frame 138 as framebuffer_frames\00138.raw
# Saved frame 139 as framebuffer_frames\00139.raw
# Saved frame 140 as framebuffer_frames\00140.raw
# Finished extracting frames. Total frames: 141

# %%
from moviepy import VideoFileClip, ImageSequenceClip
from PIL import Image
import numpy as np

# 定义屏幕宽高
screen_width = 368
screen_height = 552

# 输入和输出视频文件路径
input_video_path = 'your_video (2).mp4'
output_video_path = 'output_video.mp4'

# 设置模式：1表示原来处理方式，2表示避免黑边的处理方式
mode = 2  # 设置为1或2

def process_frame(frame, mode):
    """处理每一帧：根据模式进行处理"""
    # 转换为Pillow图像对象
    pil_image = Image.fromarray(frame)
    
    # 获取原始视频帧的宽高
    original_width, original_height = pil_image.size

    if mode == 1:
        # 模式1: 缩放帧，保持宽高比例，再裁剪到目标尺寸（可能会有黑边）
        pil_image = pil_image.resize((int(original_width * min(screen_width / original_width, screen_height / original_height)), 
                                      int(original_height * min(screen_width / original_width, screen_height / original_height))))
        
        # 计算裁剪区域，按中心裁剪
        left = (pil_image.width - screen_width) / 2
        top = (pil_image.height - screen_height) / 2
        right = (pil_image.width + screen_width) / 2
        bottom = (pil_image.height + screen_height) / 2
        
        # 裁剪图像
        pil_image = pil_image.crop((left, top, right, bottom))
        
    elif mode == 2:
        # 模式2: 按屏幕宽高比裁剪视频，避免黑边
        screen_ratio = screen_width / screen_height
        video_ratio = original_width / original_height

        if video_ratio > screen_ratio:
            # 视频宽高比大于屏幕宽高比，裁剪宽度
            new_width = int(original_height * screen_ratio)
            left = (original_width - new_width) / 2
            pil_image = pil_image.crop((left, 0, left + new_width, original_height))
        elif video_ratio < screen_ratio:
            # 视频宽高比小于屏幕宽高比，裁剪高度
            new_height = int(original_width / screen_ratio)
            top = (original_height - new_height) / 2
            pil_image = pil_image.crop((0, top, original_width, top + new_height))
        # 如果视频宽高比等于屏幕宽高比，则不做裁剪，直接缩放
        
        # 缩放到目标尺寸
        pil_image = pil_image.resize((screen_width, screen_height))

    # 转换回NumPy数组
    return np.array(pil_image)

# 加载输入视频
clip = VideoFileClip(input_video_path)

# 使用 iter_frames 获取每一帧并处理
frames = []
for frame in clip.iter_frames(fps=clip.fps, dtype='uint8'):
    processed_frame = process_frame(frame, mode)
    frames.append(processed_frame)

# 使用处理后的帧生成新的视频
processed_clip = ImageSequenceClip(frames, fps=clip.fps)

# 输出处理后的视频
processed_clip.write_videofile(output_video_path, codec="libx264", fps=clip.fps)
# Out:
# MoviePy - Building video output_video.mp4.
# MoviePy - Writing video output_video.mp4
# MoviePy - Done !
# MoviePy - video ready output_video.mp4

# %%
import cv2
import os

# 视频文件路径
video_file = "output_video.mp4"
output_folder = "video_frames"

# 创建存放视频帧的文件夹
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 打开视频文件
cap = cv2.VideoCapture(video_file)

# 获取视频的总帧数
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

if not cap.isOpened():
    print("Error: Couldn't open video file.")
    exit()

frame_num = 0

while True:
    ret, frame = cap.read()

    if not ret:
        break  # 如果读取不到帧，则退出

    # 构造文件路径
    frame_filename = os.path.join(output_folder, f"frame_{frame_num:04d}.jpg")

    # 保存每帧为jpg文件
    cv2.imwrite(frame_filename, frame)
    
    frame_num += 1

cap.release()
print(f"Finished processing {frame_num} frames.")
# Out:
# Finished processing 141 frames.
